# %%
#dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pprint

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
engine = create_engine("sqlite:///database/homecare.db")

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['homecare']

# %%
#store tables
homecare = Base.classes.homecare

# %%
# Design a query to retrieve the last 12 months of services(ncs	pts	sps	hhas) data.
# Select only the date and service quality ratings.
# Load the query results into a Pandas DataFrame and set the index to the date column.
# Plot the results using the DataFrame plot method.

# %%
#create session
session = Session(engine)

# %%
#inspect homecare table
homecare_data = session.query(homecare)
homecare_data.__dict__
# Out:
# {'_entities': [<sqlalchemy.orm.query._MapperEntity at 0x1a08ed7c88>],
#  '_has_mapper_entities': True,
#  '_mapper_adapter_map': {sqlalchemy.ext.automap.homecare: (<Mapper at 0x1a08eadac8; homecare>,
#    None)},
#  '_polymorphic_adapters': {},
#  '_primary_entity': <sqlalchemy.orm.query._MapperEntity at 0x1a08ed7c88>,
#  'session': <sqlalchemy.orm.session.Session at 0x1a08ead898>}

# %%
# # import pprint
# sql = 'select * from homecare'

# rows = engine.execute(str(sql))

# for row in rows:
#     pprint.pprint(dict(row ))#.strftime("%d-%m-%y")
#     print("__________________\n")

# %%
# query = session.query(homecare).order_by(homecare.cer_no)
# for _row in query.all():
#     print (_row.cer_no, _row.name)

# %%
# for i in homecare.__table__.columns:
#     print(i.name)

[i.name for i in homecare.__table__.columns]
# Out:
# ['cer_no',
#  'country',
#  'state',
#  'abbv',
#  'county',
#  'city',
#  'address',
#  'zipcode_x',
#  'loc_no',
#  'name',
#  'date_cer',
#  'ownership',
#  'lrd',
#  'ncs',
#  'pts',
#  'sps',
#  'hhas',
#  'sq',
#  'sqr',
#  'c_sqr',
#  'latitude',
#  'longitude',
#  'zipcode_y',
#  'Population',
#  'Male',
#  'Female',
#  'MedianAge',
#  'Race',
#  'PovertyCount',
#  'PovertyRate',
#  'HouseholdIncome',
#  'PerCapitaIncome',
#  'UnemploymentCount',
#  'UnemploymentRate',
#  'Totalhousingunits',
#  'Medianyearstructurebuilt',
#  'MedianValueforHousingUnits',
#  'Whitealonerace',
#  'BlackorAfricanAmericanalone',
#  'AmericanIndianandAlaskaNativealone',
#  'Asianalone',
#  'Someotherracealone']

# %%
[i for i in session.query(homecare.Population, func.count(homecare.cer_no)).order_by(func.count(homecare.cer_no), homecare.Population).group_by(homecare.zipcode_x).filter(homecare.state=="Maryland")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-be6501adcead> in <module>()
# ----> 1 [i for i in session.query(homecare.Population, func.count(homecare.cer_no)).order_by(func.count(homecare.cer_no), homecare.Population).group_by(homecare.zipcode_x).filter(homecare.state=="Maryland")]
#
# NameError: name 'func' is not defined

# %%
care_demographics= session.query(homecare.city,
                      func.count(homecare.cer_no), 
                      func.sum(homecare.Population),
                      homecare.PovertyRate,
                     homecare.HouseholdIncome,
                                 func.sum(homecare.BlackorAfricanAmericanalone),
                               func.sum( homecare.Whitealonerace)).group_by(homecare.city).filter(homecare.state=="Maryland")

care_demographics.all()[0]
care_demographics_dict={
    "City":care_demographics.all()[0][0],
    "Number of Provider Companies":care_demographics.all()[0][1],
    "Population":care_demographics.all()[0][2],
    "Poverty Rate":int(care_demographics.all()[0][3]),
    "Household Income":int(care_demographics.all()[0][4]),
    "Total # Blackor African American Race":int(care_demographics.all()[0][5]),
    "Total # White race":int(care_demographics.all()[0][6])
}
care_demographics_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5fbd1679cea4> in <module>()
#       1 care_demographics= session.query(homecare.city,
# ----> 2                       func.count(homecare.cer_no),
#       3                       func.sum(homecare.Population),
#       4                       homecare.PovertyRate,
#       5                      homecare.HouseholdIncome,
#
# NameError: name 'func' is not defined

# %%
query = session.query(homecare).order_by(homecare.cer_no)
query = session.query(homecare).order_by(homecare.cer_no)


for _row in query.all():
    print (_row.cer_no, _row.name)
# Out:
# 17000 BUREAU OF HOME & COMMUNITY SERVICES
# 17008 JEFFERSON COUNTY HOME CARE
# 17009 ALACARE HOME HEALTH & HOSPICE
# 17013 GENTIVA HEALTH SERVICES
# 17014 AMEDISYS HOME HEALTH
# 17016 SOUTHEAST ALABAMA HOMECARE
# 17017 SOUTHERN RURAL HEALTH CARE
# 17018 GENTIVA HEALTH SERVICES
# 17020 AMEDISYS HOME HEALTH CARE
# 17024 SOUTHEAST ALABAMA HOMECARE
# 17025 SAAD HEALTHCARE
# 17026 GENTIVA HEALTH SERVICES
# 17027 DECATUR MORGAN HOMECARE
# 17028 CENTRAL ALABAMA HOMECARE
# 17034 COMFORT CARE COASTAL HOME HEALTH
# 17035 INFIRMARY HOMECARE
# 17037 BAPTIST HOME HEALTH
# 17039 AMEDISYS HOME HEALTH OF HUNTSVILLE
# 17041 ALABAMA HOMECARE
# 17048 GENTIVA HEALTH SERVICES
# 17050 SPECTRUM HOME HEALTH AGENCY
# 17051 AMEDISYS HOME HEALTH LAKESHORE OF BIRMINGHAM
# 17052 GENTIVA HEALTH SERVICES
# 17053 CARESOUTH HOMECARE PROFESSIONALS
# 17054 GENTIVA HEALTH SERVICES
# 17055 GENTIVA HEALTH SERVICES
# 17056 GENTIVA HEALTH SERVICES
# 17058 GENTIVA HEALTH SERVICES
# 17063 INTREPID USA HEALTHCARE SERVICES
# ...

# %%
#get homecare count, has been checked with measurement station count
from sqlalchemy import func
num_providers = session.query(Homecares.ncs).group_by(Homecares.Population).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-fd339a11ab1a> in <module>()
#       1 #get homecare count, has been checked with measurement station count
#       2 from sqlalchemy import func
# ----> 3 num_providers = session.query(Homecares.ncs).group_by(Homecares.Population).count()
#
# NameError: name 'Homecares' is not defined

# %%
num_providers

# %%
#dynamically creates dates from most recent date to a year before
from datetime import datetime
most_current = session.query(homecare.lrd).order_by(homecare.lrd.desc()).first()
last_date = most_current[0]
year_before = last_date.replace(year = (last_date.year - 1))
year_before = year_before.strftime("%Y-%m-%d")
year_before

# %%
#query tables to get count of daily report, all temp data is complete for each record, so the count
#reflects a count of a provider data, Service data may or may not have been reported on that date
activity = session.query(Homecares.cer_no, Homecares.name, Homecares.zipcode_x, func.count(Homecares.Population))#.filter(Homecares.station == Homecares.station).group_by(Homecares.station).order_by(func.count(Measurements.tobs).desc()).all()

# %%
for rows in activity.all():
    pprint.pprint(rows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ba60ccec3f60> in <module>()
# ----> 1 for rows in activity.all():
#       2     pprint.pprint(rows)
#
# NameError: name 'activity' is not defined

# %%
homecarejson=pd.read_json("Resources/homecare.json")
homecarejson.head().features[2]['properties']
# Out:
# {'American Indian and Alaska Native alone': 9,
#  'Asian alone': 82,
#  'Black or African American alone': 0,
#  'Female': 1520,
#  'Household Income': 73062,
#  'Male': 2235,
#  'Median Age': 40,
#  'Median Value for Housing Units': 537600,
#  'Median year structure built': 1987,
#  'Per Capita Income': 34154,
#  'Population': 3755,
#  'Poverty Count': 194,
#  'Poverty Rate': 5.16644474,
#  'Race': 3755,
#  'Some other race alone': 0,
#  'Total housing units': 5241,
#  'Unemployment Count': 154,
#  'Unemployment Rate': 4.101198402,
#  'White alone race': 3557,
#  'abbv': 'CO',
#  'address': '18 SCHOOL ROAD SUITE 100',
#  'c_sqr': 3.5,
#  'cer_no': 67044,
#  'city': 'FRISCO',
#  'country': 'United States',
#  'county': 'Summit',
#  'date_cer': '4/1/79',
#  'hhas': 'YES',
#  'latitude': 39.5812488,
#  'loc_no': 21252,
#  'longitude': -106.0928146,
#  'lrd': '4/1/09',
#  'name': 'BRISTLECONE HEALTH SERVICES',
#  'ncs': 'YES',
#  'ownership': 'Non - Profit Religious',
#  'pts': 'YES',
# ...

# %%
# flask dependencies
from flask import Flask, jsonify, render_template

#  Flask set up
app = Flask(__name__)

# Database set up and connection
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, desc  #what else here???

# #import custom functions
# from bbd import return_sample_names

engine = create_engine("sqlite:///Resources/homecare.db")

Base = automap_base()
Base.prepare(engine, reflect=True)

homecare = Base.classes.homecare
# Samples = Base.classes.samples
# Samples_metadata = Base.classes.samples_metadata

#create session 
session = Session(engine)

# %%
care_cluster= session.query(homecare.cer_no, homecare.name, homecare.address, homecare.city,homecare.zipcode_x,
                            homecare.latitude,homecare.longitude, homecare.loc_no,homecare.ownership, 
                            homecare.sq, homecare.Population)
            
care_cluster_dict ={} 
for provider in care_cluster.all():
    care_cluster_dict["Certification #"]= provider[0]
    care_cluster_dict["Provider Address"]= provider[1]
    care_cluster_dict["provider City"]= provider[2]
    care_cluster_dict["Provider Zipcode"]= provider[3]
    care_cluster_dict["Lat"]= provider[5]
    care_cluster_dict["Long"]= provider[6]
    care_cluster_dict["Location Number"]= provider[6]
    care_cluster_dict["Ownership"]= provider[7]
    care_cluster_dict["Service quality"]= provider[8]
    care_cluster_dict["Population"]= provider[9]

care_cluster.all()[0]
# Out:
# (17000,
#  'BUREAU OF HOME & COMMUNITY SERVICES',
#  '201 MONROE STREET THE RSA TOWER  SUITE 1200',
#  'MONTGOMERY',
#  '36104',
#  '32.3791774',
#  '-86.3058201',
#  3077,
#  'Government - State/ County',
#  'Not Available',
#  8056)

# %%
# import MySQLdb
import json
from shapely.geometry  import  Point,mapping

care_cluster_dict ={} 
gjson_dict={}
gjson_dict["type"]= "Feature"
feat_list = []

# Loop through all the courses, building a list entry which is itself a dictionary
# Each of these dictionaries has nested within it a type dictionary, which contains a point dictionary and a properties dictionary 
for crs in care_cluster.all():
	type_dict = {}
	pt_dict = {}
	prop_dict = {}
	
	type_dict["type"]= "Feature"
    	
	pt_dict["type"]="Point"
	
    # GEOJSON looks for long,lat so reverse order
	type_dict["geometry"]=mapping(Point(crs[5],crs[6]))
    

	prop_dict["Certification"]= crs[0]
	prop_dict["city"]= crs[1]
	prop_dict["state"]= crs[2]
	type_dict["properties"]=prop_dict
	feat_list.append(type_dict)
    
gjson_dict["features"] = feat_list
gjson_dict

# # Serialize JSON for writing to file
# with open('c:\GolfRT\stage_geojson_blg.json', 'w') as outfile:
#      json.dump(gjson_dict, outfile, sort_keys = True, indent = 4,
# 		ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------
# ModuleNotFoundError                 Traceback (most recent call last)
# <ipython-input-60-c2554bccc1a9> in <module>()
#       1 # import MySQLdb
#       2 import json
# ----> 3 from shapely.geometry  import  Point,mapping
#       4
#       5 care_cluster_dict ={}
#
# ModuleNotFoundError: No module named 'shapely'

# %%
var geojsonFeature = {
    "type": "Feature",
    "properties": {
        "name": "Coors Field",
        "amenity": "Baseball Stadium",
        "popupContent": "This is where the Rockies play!"
    },
    "geometry": {
        "type": "Point",
        "coordinates": [-104.99404, 39.75621]
    }
};

# %%
geojsonFeature={
    "type": "Feature",
    "properties": {
        "name": "Coors Field",
        "amenity": "Baseball Stadium",
        "popupContent": "This is where the Rockies play!"
    },
    "geometry": {
        "type": "Point",
        "coordinates": [-104.99404, 39.75621]
    }
}

# %%
@app.route("/")
def home():
    return render_template("Marker_Clusters.html")

@app.route("/care_providers_cluster")
def names():
    homecare_names = Homecare.__table__.columns
    sample_names_ls = [name.key for name in sample_names]
    sample_names_ls.remove("otu_id")
    return jsonify([sample_names_ls])

@app.route("/otu")
def otu():
    otu_descriptions = session.query(Otu.lowest_taxonomic_unit_found).all()
    otu_descriptions_list = [x for (x), in otu_descriptions]
    return jsonify(otu_descriptions_list)

@app.route("/otu_descriptions")
def otu_disc():
    otu_descriptions = session.query(Otu.otu_id, Otu.lowest_taxonomic_unit_found).all()
    # otu_dict = {}
    # for row in otu_descriptions:
    #     otu_dict[row[0]] = row[1]
    otu_dict={k:v for k,sample_values in otu_descriptions  }
    return jsonify(otu_dict)

@app.route("/metadata/<sample>")
def sample_query(sample):
    sample_name = sample.replace("BB_", "")
    result = session.query(Samples_metadata.AGE, Samples_metadata.BBTYPE, Samples_metadata.ETHNICITY, Samples_metadata.GENDER, Samples_metadata.LOCATION, Samples_metadata.SAMPLEID).filter_by(SAMPLEID = sample_name).all()
    record = result[0]
    record_dict = {
        "AGE": record[0],
        "BBTYPE": record[1],
        "ETHNICITY": record[2],
        "GENDER": record[3],
        "LOCATION": record[4],
        "SAMPLEID": record[5]
    }
    return jsonify(record_dict)

@app.route('/wfreq/<sample>')
def wash_freq(sample):
    sample_name = sample.replace("BB_", "")
    result = session.query(Samples_metadata.WFREQ).filter_by(SAMPLEID = sample_name).all()
    wash_freq = result[0][0]
    return jsonify(wash_freq)

@app.route('/samples/<sample>')
def otu_data(sample):
    sample_query = "Samples." + sample
    result = session.query(Samples.otu_id, sample_query).order_by(desc(sample_query)).all()
    otu_ids = [result[x][0] for x in range(len(result))]   
    sample_values = [result[x][1] for x in range(len(result))]
    dict_list = [{"otu_ids": otu_ids}, {"sample_values": sample_values}]
    return jsonify(dict_list)

if __name__ == '__main__':
    app.run(debug=True)

# %%
# flask dependencies
from flask import Flask, jsonify, render_template
import os

#  Flask set up
# app = Flask(__name__)

# Database set up and connection
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, desc  #what else here???

# #import custom functions
# from bbd import return_sample_names

engine = create_engine("sqlite:///database/homecare.db")

Base = automap_base()
Base.prepare(engine, reflect=True)

#table class name
homecare = Base.classes.homecare
# Samples = Base.classes.samples
# Samples_metadata = Base.classes.samples_metadata

#create session 
session = Session(engine)

def get_homecareDta():
    homecareData2= session.query(homecare.latitude,homecare.longitude, homecare.name,  homecare.sq).all()
    # care_cluster_lst=[]            
    # for i in care_cluster:
        # provider_dict={k for k in i}
        # care_cluster_lst.append(provider_dict)
    return pprint.pprint(homecareData2)

# %%
get_homecareDta()
# Out:
# [('32.3791774',
#   '-86.3058201',
#   'BUREAU OF HOME & COMMUNITY SERVICES',
#   'Not Available'),
#  ('33.4032714', '-86.945411', 'JEFFERSON COUNTY HOME CARE', 'Same As Expected'),
#  ('33.4081066',
#   '-86.8048764',
#   'ALACARE HOME HEALTH & HOSPICE',
#   'Worse Than Expected'),
#  ('31.328607', '-85.817925', 'GENTIVA HEALTH SERVICES', 'Same As Expected'),
#  ('34.0715077', '-86.5870296', 'AMEDISYS HOME HEALTH', 'Same As Expected'),
#  ('31.3213521',
#   '-85.8339894',
#   'SOUTHEAST ALABAMA HOMECARE',
#   'Same As Expected'),
#  ('34.4990459', '-87.7266147', 'SOUTHERN RURAL HEALTH CARE', 'Not Available'),
#  ('33.9621937', '-86.0348832', 'GENTIVA HEALTH SERVICES', 'Same As Expected'),
#  ('30.6745872', '-88.146431', 'AMEDISYS HOME HEALTH CARE', 'Same As Expected'),
#  ('31.24734', '-85.4241629', 'SOUTHEAST ALABAMA HOMECARE', 'Same As Expected'),
#  ('30.6608514', '-88.1614208', 'SAAD HEALTHCARE', 'Same As Expected'),
# ...

# %%
def get_ServiceTypeDta():
    offerService= session.query(homecare.latitude,homecare.longitude, homecare.name,  homecare.sq,
        homecare.ncs,homecare.pts, homecare.sps,  homecare.hhas).all()
    # care_cluster_lst=[]            
    # for i in care_cluster:
        # provider_dict={k for k in i}
        # care_cluster_lst.append(provider_dict)
    return offerService

get_ServiceTypeDta()
# Out:
# [('32.3791774',
#   '-86.3058201',
#   'BUREAU OF HOME & COMMUNITY SERVICES',
#   'Not Available',
#   'YES',
#   'YES',
#   'YES',
#   'YES'),
#  ('33.4032714',
#   '-86.945411',
#   'JEFFERSON COUNTY HOME CARE',
#   'Same As Expected',
#   'YES',
#   'YES',
#   'YES',
#   'YES'),
#  ('33.4081066',
#   '-86.8048764',
#   'ALACARE HOME HEALTH & HOSPICE',
#   'Worse Than Expected',
#   'YES',
#   'YES',
#   'YES',
#   'YES'),
#  ('31.328607',
#   '-85.817925',
#   'GENTIVA HEALTH SERVICES',
#   'Same As Expected',
#   'YES',
#   'YES',
#   'NO',
#   'YES'),
#  ('34.0715077',
#   '-86.5870296',
#   'AMEDISYS HOME HEALTH',
#   'Same As Expected',
#   'YES',
#   'YES',
#   'YES',
#   'YES'),
#  ('31.3213521',
#   '-85.8339894',
#   'SOUTHEAST ALABAMA HOMECARE',
#   'Same As Expected',
#   'YES',
#   'YES',
#   'YES',
#   'NO'),
#  ('34.4990459',
#   '-87.7266147',
#   'SOUTHERN RURAL HEALTH CARE',
#   'Not Available',
#   'YES',
#   'YES',
#   'YES',
#   'YES'),
#  ('33.9621937',
# ...
